# %%
from contextlib import closing
from core.Database.connection import connection 
from core.Database.password import Password ########## Change vs old connection
from teradata import UdaExec ######################### Change vs old connection
import pandas as pd
import math

file_path = r'C:\Users\249916\OneDrive - CarMax\Desktop\Advent Of Code\dec 2.csv' #ex. '\\oak\fs_mktplanshared\...'
df = pd.read_csv(file_path,skip_blank_lines=False, encoding= 'cp1252')
df = df.replace('A', 'Rock')
df = df.replace('X', 'Lose')
df = df.replace('B', 'Paper')
df = df.replace('Y', 'Draw')
df = df.replace('C', 'Scissors')
df = df.replace('Z', 'Win')
df
# Out:
#      First Elf Second Elf
# 0     Scissors       Draw
# 1     Scissors        Win
# 2        Paper        Win
# 3         Rock        Win
# 4         Rock        Win
# 5         Rock       Draw
# 6         Rock        Win
# 7     Scissors       Draw
# 8     Scissors        Win
# 9         Rock       Draw
# 10        Rock       Draw
# 11       Paper       Lose
# 12        Rock       Draw
# 13    Scissors        Win
# 14    Scissors        Win
# 15       Paper       Lose
# 16    Scissors        Win
# 17        Rock        Win
# 18       Paper       Draw
# 19    Scissors        Win
# 20        Rock       Draw
# 21    Scissors       Lose
# 22       Paper       Draw
# 23        Rock        Win
# 24       Paper       Draw
# 25    Scissors        Win
# 26       Paper        Win
# 27       Paper       Draw
# 28    Scissors        Win
# 29        Rock        Win
# ...        ...        ...
# 2470      Rock       Lose
# 2471  Scissors        Win
# 2472  Scissors        Win
# ...

# %%
points = 0
firstElf = "None"
#currentCals = 0
pointsList = []
for index, row in df.iterrows():
    #rint(currentCals)
    myPick = row['Second Elf']
    opponentElf = row['First Elf']
    #print(firstElf)
    #print(row['Second Elf'])
    if(myPick == "Rock"):
        points = points + 1
    elif(myPick == "Paper"):
        points = points + 2
    elif(myPick == "Scissors"):
        points = points + 3
        
    if(myPick == opponentElf): #Draw
        #print("draw")
        points = points + 3
    elif(myPick == "Rock" and opponentElf == "Scissors"):
        points = points + 6
    elif(myPick == "Paper" and opponentElf == "Rock"):
        points = points + 6
    elif(myPick == "Scissors" and opponentElf == "Paper"):
        points = points + 6
        
    #print(points)
points
# Out:
# 13526

# %%
points = 0
firstElf = "None"
#currentCals = 0
pointsList = []
for index, row in df.iterrows():
    #rint(currentCals)
    whatIShouldDo = row['Second Elf']
    opponentElf = row['First Elf']
    myPick = "Donkey"
    
    if(whatIShouldDo == "Draw"): #Draw
        #print("draw")
        points = points + 3
        myPick = opponentElf
    elif(whatIShouldDo == "Lose" and opponentElf == "Scissors"):
        myPick = "Paper"
    elif(whatIShouldDo == "Lose" and opponentElf == "Paper"):
        myPick = "Rock"
    elif(whatIShouldDo == "Lose" and opponentElf == "Rock"):
        myPick = "Scissors"
    elif(whatIShouldDo == "Win" and opponentElf == "Scissors"):
        myPick = "Rock"
        points = points + 6
    elif(whatIShouldDo == "Win" and opponentElf == "Paper"):
        myPick = "Scissors"
        points = points + 6
    elif(whatIShouldDo == "Win" and opponentElf == "Rock"):
        myPick = "Paper"
        points = points + 6
    #print(firstElf)
    #print(row['Second Elf'])
    if(myPick == "Rock"):
        points = points + 1
    elif(myPick == "Paper"):
        points = points + 2
    elif(myPick == "Scissors"):
        points = points + 3
    #print(myPick)    

        
    #print(points)
points
# Out:
# 14204

# %%
df
# Out:
#      First Elf Second Elf
# 0     Scissors       Draw
# 1     Scissors        Win
# 2        Paper        Win
# 3         Rock        Win
# 4         Rock        Win
# 5         Rock       Draw
# 6         Rock        Win
# 7     Scissors       Draw
# 8     Scissors        Win
# 9         Rock       Draw
# 10        Rock       Draw
# 11       Paper       Lose
# 12        Rock       Draw
# 13    Scissors        Win
# 14    Scissors        Win
# 15       Paper       Lose
# 16    Scissors        Win
# 17        Rock        Win
# 18       Paper       Draw
# 19    Scissors        Win
# 20        Rock       Draw
# 21    Scissors       Lose
# 22       Paper       Draw
# 23        Rock        Win
# 24       Paper       Draw
# 25    Scissors        Win
# 26       Paper        Win
# 27       Paper       Draw
# 28    Scissors        Win
# 29        Rock        Win
# ...        ...        ...
# 2470      Rock       Lose
# 2471  Scissors        Win
# 2472  Scissors        Win
# ...
